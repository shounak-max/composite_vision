# %% [markdown]
# # CompositeVision Prototype Execution Notebook
#
# This notebook runs the complete pipeline for the CompositeVision research prototype.

# %%
# !pip install torch torchvision timm transformers open_clip_torch pandas numpy matplotlib seaborn scikit-learn tqdm ipywidgets

# %%
# !git clone https://github.com/your-username/composite_vision_research.git
# %cd composite_vision_research

# %%
import os
import sys
sys.path.append(os.getcwd())

from src.experiments.runner import run_full_pipeline

# Run the full experiment pipeline
run_full_pipeline()
